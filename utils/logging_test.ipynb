# %%
import pandas as pd
import sys
import os
# Get the absolute path of the directory where the notebook is currently running
# This usually is /path/to/app/folder_notebook
notebook_dir = os.getcwd()

# Get the absolute path of the 'app' directory (parent of folder_notebook)
main_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
db_path = os.path.join(main_dir, 'data', 'planet_fone.db')
if main_dir not in sys.path:
    sys.path.append(main_dir)
    
from utils import sql
from utils import utilities
from models.genetic_ops import fragmentation_score
# Out:
# 2025-05-24 10:11:44,583 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:11:44,590 - INFO - get_table - Completed function: get_table
# 2025-05-24 10:11:44,591 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:11:44,604 - INFO - get_table - Completed function: get_table
# 2025-05-24 10:11:44,604 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:11:44,606 - INFO - get_table - Completed function: get_table
# 2025-05-24 10:11:44,609 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:11:44,622 - INFO - get_table - Completed function: get_table
# 2025-05-24 10:11:44,623 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:11:44,625 - INFO - get_table - Completed function: get_table

# %%
lst = [3,2,1,1,2,3,3,2,1,1,2,3,3,2,1,1,2,3]
fragmentation_score(lst)
# Out:
# 2025-05-24 10:11:44,634 - INFO - fragmentation_score - Executing function: fragmentation_score
# 2025-05-24 10:11:44,634 - INFO - fragmentation_score - Fragmentation score: 0.816496580927726
# 2025-05-24 10:11:44,635 - INFO - fragmentation_score - Completed function: fragmentation_score
# 0.816496580927726

# %%
circuits_df = pd.DataFrame([
    {"circuit_name": "BAHSAK", "cluster_id": "2", "start_freq_prob": 0.23076923076923078, "end_freq_prob": 0.0},
    {"circuit_name": "AUSMEL", "cluster_id": "1", "start_freq_prob": 0.7307692307692307, "end_freq_prob": 0.0},
    {"circuit_name": "CHISHA", "cluster_id": "5", "start_freq_prob": 0.0, "end_freq_prob": 0.038461538461538464},
    {"circuit_name": "JAPSUZ", "cluster_id": "5", "start_freq_prob": 0.0, "end_freq_prob": 0.11538461538461539},
    {"circuit_name": "SAUJED", "cluster_id": "2", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "USAMIA", "cluster_id": "3", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "ITAIMO", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "MONMON", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "SPACAT", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "CANMON", "cluster_id": "3", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "AUSSPI", "cluster_id": "0", "start_freq_prob": 0.038461538461538464, "end_freq_prob": 0.0},
    {"circuit_name": "UKGSIL", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "BELSPA", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "HUNBUD", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "NETZAN", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "ITAMON", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "AZEBAK", "cluster_id": "0", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "SINMAR", "cluster_id": "6", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "USAAUS", "cluster_id": "3", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "MEXMEX", "cluster_id": "3", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "BRASAO", "cluster_id": "4", "start_freq_prob": 0.0, "end_freq_prob": 0.2692307692307692},
    {"circuit_name": "USALAS", "cluster_id": "3", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "QATLUS", "cluster_id": "2", "start_freq_prob": 0.0, "end_freq_prob": 0.0},
    {"circuit_name": "UAEYAS", "cluster_id": "2", "start_freq_prob": 0.0, "end_freq_prob": 0.5384615384615384}
])
GEO_DF = sql.get_table('fone_geography', db_path)
# Out:
# 2025-05-24 10:13:12,393 - INFO - get_table - Executing function: get_table
# 2025-05-24 10:13:12,395 - INFO - get_table - Completed function: get_table

# %%
merged_df = circuits_df.merge(
    GEO_DF[['code_6', 'circuit_x', 'city_x', 'country_x', 'latitude', 'longitude']],
    left_on='circuit_name',
    right_on='code_6',
    how='left'
)
merged_df = merged_df.drop(columns=['code_6'])

# %%
merged_df
# Out:
#    circuit_name cluster_id  start_freq_prob  end_freq_prob          circuit_x  \
# 0        BAHSAK          2         0.230769       0.000000             Sakhir
# 1        AUSMEL          1         0.730769       0.000000          Melbourne
# 2        CHISHA          5         0.000000       0.038462           Shanghai
# 3        JAPSUZ          5         0.000000       0.115385             Suzuka
# 4        SAUJED          2         0.000000       0.000000             Jeddah
# 5        USAMIA          3         0.000000       0.000000              Miami
# 6        ITAIMO          0         0.000000       0.000000              Imola
# 7        MONMON          0         0.000000       0.000000        Monte Carlo
# 8        SPACAT          0         0.000000       0.000000          Catalunya
# 9        CANMON          3         0.000000       0.000000           Montreal
# 10       AUSSPI          0         0.038462       0.000000          Spielberg
# ...
